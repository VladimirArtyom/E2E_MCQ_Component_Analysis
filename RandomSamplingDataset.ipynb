# %%
import pandas as pd
import numpy as np

# %%
dg_all_test = "dg_test_all_for_analysis_final.csv"
dg_1_test = "dg_test_1_for_analysis_final.csv"
dataset_dg_all = pd.read_csv(dg_all_test)
dataset_dg_1 = pd.read_csv(dg_1_test)

# %%
np.random.seed(10)
sampled_dg_1_index = dataset_dg_1.sample(n=100).index
sampled_dg_all = dataset_dg_all.iloc[sampled_dg_1_index]
sampled_dg_1 = dataset_dg_1.iloc[sampled_dg_1_index]

# %%
sampled_dg_1.head(2)
# Out:
#       Unnamed: 0                                            context  \
# 2777        2777  Saat itu pukul 07.00 di Kyoto, Jepang, dan per...
# 1303        1303  Sejarah penuh dengan kasus di mana mimpi menja...
#
#                                 question  \
# 2777       Penulis sampai di bandara _ .
# 1303  Penulis mungkin berpikir bahwa _ .
#
#                                                 correct  \
# 2777    dengan menaiki mobil Mike dari perusahaan taksi
# 1303  perasaan gugup dapat menghentikan seseorang me...
#
#                                          incorrect_1  \
# 2777            bersama bantuan Mike dari kantor pos
# 1303  Loewi seharusnya tidak melakukan eksperimennya
#
#                                             incorrect_2  \
# 2777   dengan mendapatkan tumpangan di mobil yang lewat
# 1303  bermimpi sangat kecil nilainya bagi kebanyakan...
#
#                                             incorrect_3  \
# 2777  dengan bantuan supir taksi yang diutus oleh pe...
# ...

# %%
sampled_dg_all.head(2)
# Out:
#       Unnamed: 0                                            context  \
# 2777        2777  Saat itu pukul 07.00 di Kyoto, Jepang, dan per...
# 1303        1303  Sejarah penuh dengan kasus di mana mimpi menja...
#
#                                 question  \
# 2777       Penulis sampai di bandara _ .
# 1303  Penulis mungkin berpikir bahwa _ .
#
#                                                 correct  \
# 2777    dengan menaiki mobil Mike dari perusahaan taksi
# 1303  perasaan gugup dapat menghentikan seseorang me...
#
#                                          incorrect_1  \
# 2777            bersama bantuan Mike dari kantor pos
# 1303  Loewi seharusnya tidak melakukan eksperimennya
#
#                                             incorrect_2  \
# 2777   dengan mendapatkan tumpangan di mobil yang lewat
# 1303  bermimpi sangat kecil nilainya bagi kebanyakan...
#
#                                             incorrect_3  \
# 2777  dengan bantuan supir taksi yang diutus oleh pe...
# ...

# %%
sampled_dg_1.to_excel("dg_1_test_for_analysis_100_final.xlsx", index=False)
sampled_dg_all.to_excel("dg_all_test_for_analysis_100_final.xlsx", index=False)
